# %%
import pandas as pd
import numpy as np
import re
import spacy
import en_core_med7_lg
import pickle
from spellchecker import SpellChecker
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer 
from nltk.corpus import stopwords


pd.options.display.max_colwidth = 100

# %% [markdown]
# ## Load data

# %%
df_raw = pd.read_csv("./data/wh_data_prepared.csv")
df_raw.head()
# Out:
#                                                                                            description  \
# 0  MENTAL STATE - ALTERATION IN. ETOH AFFECTED, WANTS TO KILL SELF. HX MULTIPLE PRESENTATIONS WITH ...
# 1                                  POISONING / OVERDOSE- 30MG DIAZEPAM+ETOH PHX RECENT DEATH IN FAMILY
# 2  MENTAL STATE - ALTERATION IN - FOUND LYING ON ROAD BY POLICE. ETOH EFFECTED CRYING, STATING WANT...
# 3                                     MENTAL STATE - SUICIDE ATTEMPT / RISK, PT WALKED IN FRONT OF CAR
# 4  PT ACTING ABNORMALLY SINCE HAVING MISCARRIAGE 3/12 AGO, TODAY BEEN BITING RELATIVES, SCREAMING A...
#
#                                                                                                   text  \
# 0         ALTERNATES B/W AGGRESSION AND SETTLED, STATES NEEDS ADMISSION TO PSYCH. NO APPARENT INJURIES
# 1                         GCS12, PATENT AIRWAY, SPEAKS CLEARLY, INTOXICATED, APPEARS NEAT PRESENTATION
# 2  CRYING STATNG DOESN'T WANT TO BE HERE ANY MOR. STATES EX PARTNER ABUSED HER OVERNIGHT. FAMILY HA...
# 3  RECEIVING CONGNITIVE THERAPY POST ENDING A TRAUMATIC R/SHIP 8/12 AGO, T 36.4, P 97 REG, STRONG R...
# 4  PT CHATTING FREELY, HAS NO RECOLLECTION OF TODAYS EVENTS, STATES LAST MEMORY IS FIREWORKS AND DA...
#
#    SH  SI  SISH  \
# 0   0   1     1
# 1   1   0     2
# 2   0   1     1
# 3   0   1     1
# 4   0   0     0
#
#                                                                                                comment  \
# 0  mental state - alteration in. etoh affected, wants to kill self. hx multiple presentations with ...
# 1  poisoning / overdose- 30mg diazepam+etoh phx recent death in family. gcs12, patent airway, speak...
# 2  mental state - alteration in - found lying on road by police. etoh effected crying, stating want...
# 3  mental state - suicide attempt / risk, pt walked in front of car. receiving congnitive therapy p...
# 4  pt acting abnormally since having miscarriage 3/12 ago, today been biting relatives, screaming a...
#
#    length
# 0     194
# 1     145
# 2     269
# 3     396
# 4     297

# %%
df_raw = df_raw[:100].copy()

# %% [markdown]
# ## Examine the dataset for patterns

# %% [markdown]
# **Find and extract a pattern from the dataframe**

# %%
def find_pattern(df, pattern, context=True):
    tmp = df[df.comment.str.contains(pattern)]
    print("Found {} rows.".format(tmp.shape[0]))
    for ind, row in tmp.iterrows():
        if context:
            print(ind, ": ", re.findall(".{10}" + pattern + ".{10}", row.comment))
        else:
            print(ind, ": ", re.findall(pattern, row.comment))

# %%
# %%time
find_pattern(df_new, "aggi")

# %%
# %%time
find_pattern(df_raw, "/7\s", context=False)

# %%
tmp = df_raw.loc[34992,'comment']
tmp

# %%
patter = re.compile("(?:\d)x")
tmp = patter.sub(r" times ", tmp)
tmp

# %% [markdown]
# ## Create a preprocessing pipeline

# %%
def preprocess(df):
    cleaned = []
    for ind, row in df.iterrows():
        
        # convert to lower case
        comment = row.comment.lower()
        
### Handling errors in WH data extraction
        # Remove "\x7f"
        pattern = re.compile(r"\x7f")
        comment = pattern.sub(r" ", comment)
        
#         # Remove ";" in the middle of a word
#         pattern = re.compile("(\S);(\S)")
#         comment = pattern.sub(r"\1\2", comment)
        
#         # Remove "[" in the middle of a word
#         pattern = re.compile("(\w)\[(\w)")
#         comment = pattern.sub(r"\1\2", comment)
        
        # Remove what might mean "with"
        pattern = re.compile("`/c")
        comment = pattern.sub(r" ", comment)
    
### General rules for punctuation 
        # "l)" to "left"
        pattern = re.compile("(\W)l\)")
        comment = pattern.sub(r"\1 left ", comment)
        
        # "r)" to "right"
        pattern = re.compile("(\W)r\)")
        comment = pattern.sub(r"\1 right ", comment)

        # "can't" to "cannot"
        pattern = re.compile("can't")
        comment = pattern.sub(r" can not ", comment)
        
        # "n't" to "not"
        pattern = re.compile("n't")
        comment = pattern.sub(r" not ", comment)
        
        # Drop 's, 'll, 've, 'm, 're
        pattern = re.compile("\'(s|ll|ve|m|re)(?!\w)")
        comment = pattern.sub(r" ", comment)
        
        # Remove ' in the middle of a word
        pattern = re.compile("\w\'\w")
        comment = pattern.sub(r"", comment)
        
        # Abstract float numbers
        pattern = re.compile("\d+\.\d+")
        comment = pattern.sub(r" float ", comment)
        
        # "?" to "question"
        pattern = re.compile("\?+")
        comment = pattern.sub(r" question ", comment)
        
        # "@" to "at"
        pattern = re.compile("@")
        comment = pattern.sub(r" at ", comment)
        
        # "#" not followed by number to "fractured"
        pattern = re.compile("#(?!\W?\d)")
        comment = pattern.sub(r" fracture ", comment)
        
### Unmix letters and digits
        # "x" to "times"
        pattern = re.compile("x(?=\d)")
        comment = pattern.sub(r" times ", comment)
        # for some reason look behind assertion doesn't work
        patter = re.compile("(\d)x") 
        comment = patter.sub(r" \1 times ", comment)
        
        # Abstract integers
        pattern = re.compile("\d+")
        comment = pattern.sub(r" integer ", comment)
        
        # Remove the rest of non-alphanumeric and non-whitespace characters
        pattern = re.compile("[^a-zA-Z\d\s]")
        comment = pattern.sub(r" ", comment)
        
        # Oxygen saturation
#         pattern = re.compile("sat\so2|sat\s02|sao2|sa02|o2\s?sat[a-z]*|\D02\s?sat[a-z]*")
#         comment = pattern.sub(" oxygen saturation ", comment)
        
#         # Abstract dates
#         pattern = re.compile("\d{1,2}\.\d{1,2}\.\d{2,4}")
#         comment = pattern.sub(r" NUM_DATE ", comment)
        
#         # Glasgow Coma Scale response
#         pattern = re.compile("e\dv\dm\d")
#         comment = pattern.sub(r" GCS_RESPONSE ", comment)
        
#         # Type 1 diabetes
#         pattern = re.compile("t1dm")
#         comment = pattern.sub(r" type 1 diabetes ", comment)
        
#         # Type 2 diabetes
#         pattern = re.compile("t2dm")
#         comment = pattern.sub(r" type 2 diabetes ", comment)
        
        # Remove duplicated whitespace
        pattern = re.compile("\s+")
        comment = pattern.sub(r" ", comment)
        
### Spelling correction
#         comment = correct_spelling(comment)
        
        cleaned.append(comment)
    
        if ind % 10000 == 0:
            print(ind)
        
    return cleaned

# %%
# %%time
df_new = df_raw.copy()
df_new.comment = preprocess(df_raw)
# Out:
# 0
# CPU times: user 30 ms, sys: 1 ms, total: 31 ms
# Wall time: 30.6 ms

# %%
for i in range(5):
    print("***Comment {}***".format(i))
    print(df_raw.comment[i], "\n", df_new.comment[i], "\n")

# %% [markdown]
# ## Save the new dataset

# %%
df_new.drop(['description', 'text'], axis=1).to_csv("./data/" + "wh_data_prepared.csv", index=False)

# %% [markdown]
# ## Negation

# %%
### 45 and 151

import spacy
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
from negspacy.negation import Negex

nlp = spacy.load("en_core_med7_lg")

negex = Negex(nlp, language = "en_clinical")
# negex = Negex(nlp, language = "en_clinical", 
#               preceding_negations = ["denies", "no", "non", "not", "without", "unable"], 
#               termination = [".", "-", ";", "+", "and", "aox3", "but", "complains", "did", 
#                              "except", "has", "per", "pt", "reports", "secondary", "states"])

nlp.add_pipe(negex, last=True)

# %%
complaints = list(nlp.pipe(["INJURY", "MARKINGS"]))
matcher = PhraseMatcher(nlp.vocab)
matcher.add("complaints", None, *complaints)

def add_complaints(doc):
    matches = matcher(doc)
    spans = [Span(doc, start, end, label="complaints") for match_id, start, end in matches]
    doc.ents += spans
    return doc

# %%
nlp.add_pipe(add_complaints, after="ner")
print(nlp.pipe_names)

# %%
# text = "Foot is red swollen warm to the touch, denies fever at home . Hx multiple infections"
# text = "She does not like houses but denies Apple at home."
# text = "A patient denied taking Magnesium hydroxide 400mg/5ml but had suspension PO of total 30ml bid for the next 5 days"

# %%
doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.label_, ent._.negex)

# %% [markdown]
# ## Create vocab using Med7

# %%
# Step 1: create a custom word frequency list

# Load the model trained on MIMIC data
nlp = en_core_med7_lg.load()

# Create an empty spellchecker object and 
# initialise it with the words known to the model
spell_med7 = SpellChecker(language=None)
spell_med7.word_frequency.load_words(list(nlp.vocab.strings))

# Check to see how many unique and total words in the vocab
print(spell_med7.word_frequency.unique_words, spell_med7.word_frequency.total_words)

# A function that splits a string and 
# adds known words fromthe string to a list
def add_to_vocab(comment):
    words = comment.split()
    vocab.extend(spell_med7.known(words))

# Apply the function to each triage comment
vocab = []
df.comment.apply(add_to_vocab)

# Save the vocab
with open('vocab.txt', 'wb') as f:
    pickle.dump(vocab, f)

# %%
# Step 2: spelling correction
# Load the custom word frequency list
with open ('vocab.txt', 'rb') as f:
    vocab = pickle.load(f)
    
# Creat an empty spell checker object and
# initialise it with our vocabulary
spell = SpellChecker(language=None)
spell.word_frequency.load_words(vocab)

# Check to see how many unique and total words
print(spell_med7.word_frequency.unique_words, spell_med7.word_frequency.total_words)

# A function that splits a string and
# and corrects spelling based on our custom vocab
def correct_spelling(comment):
    words = comment.split()
    corrected_words = [spell.correction(word) if word in spell.unknown(words) else word for word in words]
    return ' '.join(corrected_words)

# Apply the function to each triage comment
df_new.comment = df_new.comment.apply(correct_spelling)

# %%
nlp = en_core_med7_lg.load()

# %%
spell_med7 = SpellChecker(language=None)
spell_med7.word_frequency.load_words(list(nlp.vocab.strings))

# %%
spell_med7.word_frequency.unique_words, spell_med7.word_frequency.total_words

# %%
def add_to_vocab(comment):
    words = comment.split()
    vocab.extend(spell_med7.known(words))

# %%
# %%time
vocab = []
df_new.comment.apply(add_to_vocab)

# %%
with open('./data/vocab.txt', 'wb') as f:
    pickle.dump(vocab, f)

# %% [markdown]
# ## Spelling correction

# %% [markdown]
# ### Load vocab

# %%
with open ('./data/vocab.txt', 'rb') as f:
    vocab = pickle.load(f)

# %%
spell = SpellChecker(language=None)
spell.word_frequency.load_words(vocab)

# %%
spell.word_frequency.unique_words, spell.word_frequency.total_words
# Out:
# (24771, 1772242)

# %%
{k: v for k, v in sorted(spell.word_frequency.dictionary.items(), key=lambda item: item[1])}

# %%
rare_tokens = 0
for k, v in spell.word_frequency.dictionary.items():
    if v == 1:
        rare_tokens += 1
        
rare_tokens

# %% [markdown]
# ### Process comments

# %%
def correct_spelling(comment):
    words = comment.split()
    corrected_words = [spell.correction(word) if word not in vocab else word for word in words]
    return ' '.join(corrected_words)

# %%
# %%time
df_new.comment = df_new.comment.apply(correct_spelling)

# df_new.drop(['description', 'text'], axis=1).to_csv("./data/" + "wh_data_corrected.csv", index=False)

# %% [markdown]
# ## Find rare unigrams and common bigrams

# %%
df_train = pd.read_csv("./data/rmh_train.csv")
df_train.shape
# Out:
# (311544, 10)

# %%
def word_count(data, ngram_range=(1,1)):
    vectorizer = CountVectorizer(stop_words=stopwords.words('english'), 
                                 ngram_range=ngram_range, 
                                 token_pattern=r'\S+'
                                )
    vectors = vectorizer.fit_transform(data)    
    vocab = list(vectorizer.get_feature_names())
    counts = vectors.sum(axis=0).A1
    return Counter(dict(zip(vocab, counts)))

# %%
unigrams = word_count(df.comment)
len(unigrams)

# %%
bigrams = word_count(df_train.entities, (2, 2))
len(bigrams)
# Out:
# 955481

# %%
cut_off = np.quantile(np.fromiter(bigrams.values(), dtype=np.int), 0.99) 
print("Cut-off:", cut_off)
n_bigrams = (np.fromiter(bigrams.values(), dtype=np.int) > cut_off).sum()
print("%d most common bigrams" % n_bigrams)
most_common_bigrams = [item[0] for item in bigrams.most_common(n_bigrams)]
# Out:
# Cut-off: 55.0
# 9432 most common bigrams
# ['abdo pain',
#  'chest pain',
#  't2 dm',
#  'phx nil',
#  'nil loc',
#  'sudden onset',
#  'neck pain',
#  'pain radiating',
#  'pt expect',
#  'pain nil',
#  'pain worse',
#  'pt states',
#  'pmhx nil',
#  'pain post',
#  'o/a gcs',
#  'flank pain',
#  'left arm',
#  'mechanical fall',
#  'nil relief',
#  'epigastric pain',
#  'left sided',
#  'pain phx',
#  'hr regular',
#  'central chest',
#  'nausea vomiting',
#  'productive cough',
#  'pain +',
#  'lower abdo',
#  'n v',
#  'altered sensation',
#  'lower pain',
#  'pain left',
#  'self harm',
#  'nil phx',
#  'pain right',
#  'pmh nil',
#  'referred gp',
#  'speaking sentences',
#  'neurovasc intact',
#  'pain swelling',
#  'hx nil',
#  'facial droop',
#  'chest tightness',
#  'shoulder pain',
#  '+ v',
#  'non distressed',
#  'left leg',
#  'n +',
#  'nil pain',
#  'km hr',
#  'sore throat',
#  'hs loc',
#  'sao2 ra',
#  'nil sob',
#  'right sided',
#  'post fall',
#  'headstrike loc',
#  'worse inspiration',
#  'phx ht',
#  'chest infection',
#  'left shoulder',
#  'blurred vision',
#  'denies pain',
#  'slurred speech',
#  'nausea nil',
#  'right hand',
#  'mech fall',
#  'right leg',
#  'right shoulder',
#  'nil improvement',
#  'sent gp',
#  'sided chest',
#  'talking sentances',
#  'increasing pain',
#  'c/o pain',
#  'nil hs',
#  'oral intake',
#  'c spine',
#  'seen gp',
#  'right knee',
#  'generally unwell',
#  'right arm',
#  'high chol',
#  'left hand',
#  'nil nausea',
#  'nil obvious',
#  'urinary symptoms',
#  'nil hx',
#  'resp distress',
#  'vitally stable',
#  'knee pain',
#  'pst hx',
#  'abdominal pain',
#  'nil headstrike',
#  'suicidal ideation',
#  'nil n',
#  'assoc nausea',
#  'generalised abdo',
#  'increasing sob',
#  'regular sao2',
#  'left knee',
#  'hip pain',
#  'left chest',
#  'pain free',
#  'phx asthma',
#  'pain nausea',
#  'vasc intact',
#  'pain assoc',
#  'nil analgesia',
#  'refered gp',
#  'l arm',
#  'unwitnessed fall',
#  'phx t2',
#  'pain r',
#  'worse movement',
#  'radiating left',
#  'lower leg',
#  'leg pain',
#  'pain l',
#  'right ankle',
#  'pain hx',
#  'triage phx',
#  'left eye',
#  'left ankle',
#  'associated nausea',
#  'analgesia taken',
#  'l sided',
#  'pt c/o',
#  'right foot',
#  'arm pain',
#  'denies loc',
#  'oral abs',
#  'hx ht',
#  'loc nil',
#  'phx htn',
#  'gcs phx',
#  'nil vomiting',
#  'left foot',
#  'right eye',
#  'pmx nil',
#  'pain denies',
#  'pain pain',
#  'nil urinary',
#  'dry cough',
#  'right flank',
#  'phx depression',
#  'oral ab',
#  'panadeine forte',
#  'feels like',
#  'pain pmhx',
#  't1 dm',
#  'afebrile phx',
#  'states pain',
#  'yrs ago',
#  'self resolved',
#  'nil neck',
#  'lac left',
#  'swelling pain',
#  'vomiting diarrhoea',
#  'renal colic',
#  'denies trauma',
#  'right hip',
#  'left flank',
#  'rif pain',
#  'poor historian',
#  'head strike',
#  'hit head',
#  'ongoing pain',
#  'left wrist',
#  'upper abdo',
#  'index finger',
#  'sentances non',
#  'told present',
#  'able ambulate',
#  'n vasc',
#  'gcs nil',
#  'increased pain',
#  'chronic pain',
#  'talking sentences',
#  'pain associated',
#  'called av',
#  'nv intact',
#  'sob nil',
#  'dm ht',
#  'nil resp',
#  'lumbar pain',
#  'pr bleeding',
#  'saw gp',
#  'left lower',
#  'lac right',
#  'hx t2',
#  'onset left',
#  'rib pain',
#  'right lower',
#  'pain rad',
#  'phx af',
#  'denies urinary',
#  'non radiating',
#  'triage pmhx',
#  'fall ago',
#  'states feels',
#  'low speed',
#  'left hip',
#  'hs nil',
#  'feeling unwell',
#  'worse palpation',
#  'assoc sob',
#  's/b gp',
#  'l leg',
#  'temp hr',
#  'loc c/o',
#  'right wrist',
#  'sob nausea',
#  'deep inspiration',
#  'pain o/a',
#  'self extricated',
#  'r sided',
#  'decreased rom',
#  'nil diarrhoea',
#  'gtn patch',
#  'worsening pain',
#  'hx asthma',
#  'gcs hx',
#  'l shoulder',
#  'triage hx',
#  'active bleeding',
#  'represent alert',
#  'difficult historian',
#  'nil effect',
#  'pain sob',
#  'loc gcs',
#  'pain hours',
#  'drug use',
#  'mg morphine',
#  'c/o left',
#  'unwell looking',
#  'nil chest',
#  'o/a talking',
#  'neck stiffness',
#  'r shoulder',
#  'pain unable',
#  'r leg',
#  'headstrike nil',
#  'vitals stable',
#  'ankle pain',
#  'weight bear',
#  'spine tenderness',
#  'hep c',
#  'r hand',
#  'approx km',
#  'depression anxiety',
#  'ht high',
#  'hx depression',
#  'ago nil',
#  'nil active',
#  'pain states',
#  'pain relief',
#  'recent travel',
#  'etoh abuse',
#  'frontal headache',
#  'worse today',
#  'central abdo',
#  'etoh +',
#  'cm lac',
#  'vs car',
#  'unable tolerate',
#  'pain pt',
#  'ruq pain',
#  'r arm',
#  'nil altered',
#  'years ago',
#  'nil cp',
#  'nil recent',
#  'rr sao2',
#  'onset hours',
#  'obvious deformity',
#  'sharp nature',
#  'pain today',
#  'dizziness nausea',
#  'distressed phx',
#  'pain increasing',
#  'pain gcs',
#  'r knee',
#  'nil pmhx',
#  'unable weight',
#  'mg iv',
#  'gcs hr',
#  'c/o right',
#  'l hand',
#  'triage nil',
#  'feeling dizzy',
#  'hr phx',
#  'denies neck',
#  'hours onset',
#  'referred lmo',
#  'pt reports',
#  'unconscious collapse',
#  'unable sleep',
#  'nil trauma',
#  'middle finger',
#  'hr bp',
#  'intact phx',
#  'dm htn',
#  'feeling generally',
#  'vomit x',
#  'c/o headache',
#  'oa hr',
#  'worsening sob',
#  'hx af',
#  'triage gcs',
#  'renal failure',
#  'gcs confused',
#  'post eating',
#  'intact nil',
#  'phx ami',
#  'l knee',
#  'nil fevers',
#  'pain pmh',
#  'x vomit',
#  'foot pain',
#  'nil facial',
#  'denies chest',
#  'pain sharp',
#  'increased sob',
#  'phx anxiety',
#  'unable wb',
#  'flu like',
#  'bp hr',
#  'code stroke',
#  'anxiety depression',
#  'like symptoms',
#  'o/a painfree',
#  'painful right',
#  'small lac',
#  'etoh tonight',
#  'today nil',
#  'unsteady gait',
#  'av arrival',
#  'chest discomfort',
#  'urinary bowel',
#  'eye contact',
#  'similar episode',
#  'groin pain',
#  'urinary frequency',
#  'wrist pain',
#  'headache nil',
#  'nil airway',
#  'conscious collapse',
#  'vomiting nil',
#  'alleged assault',
#  'approx cm',
#  'pmhx ht',
#  'airbags deployed',
#  'd/c rmh',
#  'thoracic pain',
#  'onset central',
#  'mcg fentanyl',
#  'radiating right',
#  'visual disturbance',
#  'left elbow',
#  'tonic clonic',
#  'pmhx t2',
#  'v +',
#  'chest heaviness',
#  'onset right',
#  'r ankle',
#  'afebrile triage',
#  'decreased oral',
#  'l chest',
#  'distressed triage',
#  'worse deep',
#  'fall standing',
#  'mental health',
#  'pins needles',
#  'av called',
#  'good effect',
#  'states feeling',
#  'pain past',
#  'pmhx asthma',
#  'spine pain',
#  'sharp pain',
#  'anxious +',
#  'gcs pearl',
#  'body aches',
#  'o/a pain',
#  'difficulty ambulating',
#  'pmh ht',
#  'sided weakness',
#  'right elbow',
#  'associated sob',
#  'dm insulin',
#  'o/a hr',
#  'hx ami',
#  'gcs o/a',
#  'swollen painful',
#  'sided abdo',
#  'pain worsening',
#  'difficulty swallowing',
#  'aches pains',
#  'phx dementia',
#  'nil neurology',
#  'fracture right',
#  'ht ^chol',
#  'l eye',
#  'r eye',
#  'r foot',
#  'recent admission',
#  'syncopal episode',
#  'x mg',
#  'urinary sx',
#  'nil radiation',
#  'pt denies',
#  'fall headstrike',
#  'ht t2',
#  'onset dizziness',
#  'phx renal',
#  'swelling right',
#  'gp today',
#  'nil recall',
#  'painful left',
#  'swelling left',
#  'fracture left',
#  'nvac intact',
#  'pain palpation',
#  'ago phx',
#  'nil distress',
#  'staff member',
#  'l foot',
#  'hx htn',
#  'equal limb',
#  'oa gcs',
#  'recall event',
#  'nil symptoms',
#  'present ed',
#  'inspiration movement',
#  'radial pulse',
#  'aspirin gtn',
#  'phx schizophrenia',
#  'phx copd',
#  'av phx',
#  'left thumb',
#  'little finger',
#  'similar previous',
#  'afebrile nil',
#  'severe pain',
#  'painfree phx',
#  'post gtn',
#  'av given',
#  'iv morphine',
#  'pain lower',
#  'pmhx htn',
#  'given mg',
#  'driver mva',
#  'seen ed',
#  'minimal relief',
#  'sob phx',
#  'loc recall',
#  'l ankle',
#  'recall events',
#  'triage pmh',
#  'chest clear',
#  'nausea +',
#  'pain vomiting',
#  'abdo cramping',
#  'hr sr',
#  'nausea vomitting',
#  'pain yesterday',
#  'direct resus',
#  'felt dizzy',
#  'af warfarin',
#  'denies fevers',
#  'lac head',
#  'obvious injuries',
#  'pain increased',
#  'able wb',
#  'pain difficulty',
#  'post ictal',
#  'denies nausea',
#  'urinary retention',
#  'calf pain',
#  'headache nausea',
#  'pain seen',
#  'radiating l',
#  'hx left',
#  'nausea phx',
#  'chemo ago',
#  'getting worse',
#  'generalised weakness',
#  'distress speaking',
#  'looks pale',
#  'sob chest',
#  'r flank',
#  'standing height',
#  'taken analgesia',
#  'lac l',
#  'o/a afebrile',
#  'right chest',
#  'gcs =',
#  'post mechanical',
#  'th finger',
#  'nausea dizziness',
#  'left ear',
#  'recent chest',
#  'seen rmh',
#  'intermittent chest',
#  'jaw pain',
#  'gcs normal',
#  'phx cva',
#  'htn ^chol',
#  'push bike',
#  'sao2 bp',
#  '+ nausea',
#  'hr irregular',
#  'right ear',
#  'short sentences',
#  'neuro vasc',
#  'pain resolved',
#  'hx right',
#  'hit car',
#  'right thumb',
#  'nil assoc',
#  'blood loss',
#  'high cholesterol',
#  'loc headstrike',
#  'gp nil',
#  'hot touch',
#  'left facial',
#  'normal pt',
#  'cardiac hx',
#  'commenced oral',
#  'renal transplant',
#  'decreased mobility',
#  'hx dementia',
#  'seizure activity',
#  'nil visual',
#  'states unable',
#  'hr temp',
#  'high speed',
#  'phx epilepsy',
#  'l wrist',
#  'gcs triage',
#  'pain decreased',
#  'nausea sob',
#  'today pain',
#  'pain night',
#  'ring finger',
#  'nil change',
#  'x episodes',
#  'increased wob',
#  'family hx',
#  'denies cp',
#  'playing football',
#  'pain urination',
#  'neuro intact',
#  'sentences nil',
#  'suicidal thoughts',
#  'left cp',
#  'onset sob',
#  'hx anxiety',
#  'big toe',
#  'painful swollen',
#  'limited rom',
#  'morphine mg',
#  'limb strength',
#  'pain non',
#  'sided facial',
#  'v nil',
#  'days ago',
#  'thoughts self',
#  'lac r',
#  's/b lmo',
#  'symptoms phx',
#  'minimal pain',
#  'l flank',
#  'nil headache',
#  'r hip',
#  'loc neck',
#  'chest pressure',
#  'playing soccer',
#  'hr bpm',
#  'left face',
#  'o/a nil',
#  'denies pmh',
#  'kidney stones',
#  'light headed',
#  'painfree post',
#  'hx renal',
#  'symptoms nil',
#  'av hx',
#  'rlq pain',
#  'av gcs',
#  'sob +',
#  'l hip',
#  'weight bare',
#  'denies sob',
#  'ago post',
#  'helmet worn',
#  'post mva',
#  'pain c/o',
#  'pain chest',
#  'pain onset',
#  'gcs afebrile',
#  'c/o nausea',
#  'gcs pmh',
#  'generalised aches',
#  'nil neuro',
#  'collar insitu',
#  'gtn spray',
#  'pmhx depression',
#  'sided cp',
#  'sob pain',
#  'swelling post',
#  'deep lac',
#  'nil injuries',
#  'pain intermittent',
#  'worse insp',
#  'oral antis',
#  'head nil',
#  'af ht',
#  'left upper',
#  'prod cough',
#  'right upper',
#  'loc o/a',
#  'non compliant',
#  'approx hours',
#  'd/c ago',
#  'denies phx',
#  'hx copd',
#  'phx cags',
#  'pt requesting',
#  'o/a unwell',
#  'c/o dizziness',
#  'found floor',
#  'pmh asthma',
#  'pmh depression',
#  'c/o neck',
#  'burning urination',
#  'brief loc',
#  'av o/a',
#  'swelling redness',
#  'ph nil',
#  'distress triage',
#  'poor oral',
#  'onset ccp',
#  'pain n',
#  'pain similar',
#  'looking hr',
#  'ped vs',
#  'arm numbness',
#  'nil significant',
#  'pain afebrile',
#  'phx recent',
#  'post etoh',
#  'ago pt',
#  'arm weakness',
#  'passing urine',
#  'past days',
#  'r wrist',
#  'facial swelling',
#  'leg weakness',
#  'mild headache',
#  'mild pain',
#  'bowel symptoms',
#  'sob productive',
#  'unable ambulate',
#  'sr monitor',
#  'bp phx',
#  'elbow pain',
#  'pain currently',
#  'requesting help',
#  'diarrhoea nil',
#  'ps nil',
#  'clonic seizure',
#  'fall ladder',
#  'gp letter',
#  'nil associated',
#  'temp triage',
#  'swelling nil',
#  'ecg changes',
#  'pain neck',
#  'hx cva',
#  'onset severe',
#  'onset sharp',
#  'hemodynamically stable',
#  'onset chest',
#  'respiratory distress',
#  'assoc symptoms',
#  'pain able',
#  'av pmhx',
#  'hx schizophrenia',
#  'speed mva',
#  'ht chol',
#  'pain movement',
#  'ear pain',
#  'en route',
#  'gp given',
#  'radiating groin',
#  'rear ended',
#  'unsteady feet',
#  'limb weakness',
#  'o/a mild',
#  'today phx',
#  'pt unable',
#  'weight loss',
#  'lower limb',
#  'pain ph',
#  'cabin intrusion',
#  'gp hx',
#  'pain recent',
#  'upper arm',
#  'hr sao2',
#  'nursing home',
#  'o/a resp',
#  'r lower',
#  'right face',
#  'ago pain',
#  'gcs pmhx',
#  'left calf',
#  'loc pain',
#  'radiating neck',
#  'difficulty breathing',
#  'fall nil',
#  'left forearm',
#  'nil swelling',
#  'sob worse',
#  'allergic reaction',
#  'cp sob',
#  'poor recall',
#  'sao2 l',
#  'swelling +',
#  'fall hs',
#  'mild swelling',
#  'peter mac',
#  'movement nil',
#  'pain diarrhoea',
#  'pain hr',
#  'htn t2',
#  'leg swelling',
#  'hand pain',
#  'recent d/c',
#  'inspiration palpation',
#  'pmhx af',
#  'speaking short',
#  'sentences hr',
#  'able weight',
#  'c/o sob',
#  'pain triage',
#  'nil abdo',
#  'o/a ps',
#  '+ pain',
#  'redness swelling',
#  'valve replacement',
#  'decreased appetite',
#  'denies headstrike',
#  'gp referral',
#  'pmh t2',
#  'ps phx',
#  'seen ago',
#  'ago o/a',
#  'looks uncomfortable',
#  'stable triage',
#  '+ vomiting',
#  'sb gp',
#  'gcs av',
#  'sharp chest',
#  'pt feels',
#  'phx ccf',
#  'c/o lower',
#  'gradual onset',
#  'mild nausea',
#  'unable recall',
#  'fall left',
#  'hours nil',
#  'intermittent left',
#  'ccp radiating',
#  'phx ihd',
#  'pr bleed',
#  'pain headache',
#  'right facial',
#  'abdo cramps',
#  'symptoms resolved',
#  'sensation left',
#  'pain improved',
#  'frank blood',
#  'htn high',
#  'pain feels',
#  'auditory hallucinations',
#  'phx ppm',
#  'ecg nad',
#  'fall right',
#  'hernia repair',
#  'pain relieved',
#  'conscious state',
#  'cough nil',
#  'loose stools',
#  'currently painfree',
#  'hr nil',
#  'swelling r',
#  'states nil',
#  'phx chronic',
#  '+ phx',
#  'l lower',
#  'nil c',
#  'nil vomit',
#  'regular bp',
#  'collared av',
#  'left neck',
#  'nil oa',
#  'onset headache',
#  'red swollen',
#  'actively bleeding',
#  'cardiac stents',
#  'right neck',
#  '+ sob',
#  'hx epilepsy',
#  'nil bowel',
#  'alt sensation',
#  'non productive',
#  'swelling l',
#  'hr triage',
#  'rmh ago',
#  'feeling sob',
#  'x vomits',
#  'chest wall',
#  'denies n',
#  'o/a phx',
#  'seat belt',
#  'brain tumour',
#  'went gp',
#  'nausea diaphoresis',
#  'temp phx',
#  'left index',
#  'nil changes',
#  'direct t1',
#  'headache dizziness',
#  'pt concerned',
#  'arm nil',
#  'burning sensation',
#  'o/a p/s',
#  'onset palpitations',
#  'home o2',
#  'intact hx',
#  'lower abdominal',
#  'yesterday nil',
#  'inguinal hernia',
#  'right calf',
#  'afebrile hx',
#  'denies headache',
#  'stable phx',
#  'fracture r',
#  'viewed triage',
#  'sob dizziness',
#  'associated symptoms',
#  'inc sob',
#  'lac forehead',
#  'mild sob',
#  'swollen right',
#  'bilateral lower',
#  'hx cags',
#  'intact pmhx',
#  'nausea diarrhoea',
#  'airway compromise',
#  'c/o feeling',
#  'cough sob',
#  'palpation nil',
#  'appears pale',
#  'mva km',
#  'onset l',
#  'eye pain',
#  'numbness left',
#  'post falling',
#  'shortening rotation',
#  'occipital headache',
#  'nil cough',
#  'ref gp',
#  'assoc dizziness',
#  'pt presents',
#  'bowel urinary',
#  'inspiration nil',
#  'bilateral leg',
#  'loc lac',
#  'today pt',
#  'hours ago',
#  'increased swelling',
#  'pt fell',
#  'hearing voices',
#  'morphine av',
#  'approx mins',
#  'assoc n',
#  'bilateral flank',
#  'direct t2',
#  'painful r',
#  'droop slurred',
#  'loc phx',
#  'nausea denies',
#  'onset lower',
#  'pain inspiration',
#  'rad left',
#  'right forearm',
#  'denies recent',
#  'sob hx',
#  'c/o chest',
#  'hours sudden',
#  'mcg gtn',
#  'phx etoh',
#  'woke hours',
#  'burning pain',
#  'fall yesterday',
#  'strong radial',
#  'onset epigastric',
#  'seat passenger',
#  'severe headache',
#  'sighted triage',
#  'left breast',
#  'pitting oedema',
#  'hand post',
#  'kidney transplant',
#  'loc denies',
#  'n surg',
#  'improved post',
#  'hx worsening',
#  'cough fevers',
#  'denies drug',
#  'phx niddm',
#  'testicular pain',
#  '+ nil',
#  'fracture post',
#  'feeling hot',
#  'bowel obstruction',
#  'lives home',
#  'pain burning',
#  'right abdo',
#  'right groin',
#  'today hx',
#  'fevers chills',
#  'weight bearing',
#  'headache +',
#  'hot cold',
#  'o/a hx',
#  'royal park',
#  'fracture l',
#  'relief panadol',
#  'tolerate oral',
#  'cp worse',
#  'dizziness nil',
#  'stable av',
#  'pain pmx',
#  'sentences sao2',
#  'ex smoker',
#  'nil photophobia',
#  'recent uti',
#  'relief gtn',
#  'visual disturbances',
#  'worsening right',
#  'fall today',
#  'pain abdo',
#  'radiating nil',
#  'hard collar',
#  'advised present',
#  'afebrile pain',
#  'landing left',
#  'movement palpation',
#  'nad phx',
#  'oral abx',
#  'vp shunt',
#  '+ swelling',
#  'ankle post',
#  'lower limbs',
#  'retrograde amnesia',
#  'sob diaphoresis',
#  'ago hx',
#  'headache phx',
#  'post mech',
#  'recent stressors',
#  'nausea pain',
#  'etoh today',
#  'gcs denies',
#  'swollen left',
#  'throat pain',
#  'appears comfortable',
#  'c/o abdo',
#  'exp wheeze',
#  'applied triage',
#  'throat tightness',
#  'today c/o',
#  'worsening left',
#  'febrile triage',
#  'pt found',
#  'right index',
#  'intact pain',
#  'o/a temp',
#  'phx smoker',
#  'diarrhoea vomiting',
#  'ht af',
#  'ongoing nausea',
#  'pain mild',
#  'av nil',
#  'dec rom',
#  'ice use',
#  'nil deformity',
#  ...]

# %%
cut_off = np.quantile(np.fromiter(bigrams.values(), dtype=np.int), 0.99) 
print("Cut-off:", cut_off)

# rare_tokens = []

# # Cut off 89% if "<4" and 91.5% if "<=4"
# for token, count in bigrams.items():
#     if count <= cut_off:
#         rare_tokens.append(token)

# print("Number of rare tokens:", len(rare_tokens))
# print("Percentage of rare tokens: {:.2f}%".format(len(rare_tokens) / len(bigrams) * 100))

# for item in rare_tokens:
#     bigrams.pop(item)
    
# print("Number of tokens left:", len(bigrams))
# Out:
# Cut-off: 55.0

# %%
sorted(bigrams.items(), key=lambda item: item[1], reverse=True)
# Out:
# [('abdo pain', 21115),
#  ('chest pain', 18004),
#  ('t2 dm', 12190),
#  ('phx nil', 11657),
#  ('nil loc', 8194),
#  ('sudden onset', 7922),
#  ('neck pain', 7455),
#  ('pain radiating', 6946),
#  ('pt expect', 6885),
#  ('pain nil', 6635),
#  ('pain worse', 6346),
#  ('pt states', 6232),
#  ('pmhx nil', 5684),
#  ('pain post', 5098),
#  ('o/a gcs', 5054),
#  ('flank pain', 4972),
#  ('left arm', 4873),
#  ('mechanical fall', 4431),
#  ('nil relief', 4430),
#  ('epigastric pain', 4336),
#  ('left sided', 4322),
#  ('pain phx', 4300),
#  ('hr regular', 4261),
#  ('central chest', 4152),
#  ('nausea vomiting', 4108),
#  ('productive cough', 4084),
#  ('pain +', 4043),
#  ('lower abdo', 4025),
#  ('n v', 3788),
#  ('altered sensation', 3776),
#  ('lower pain', 3740),
#  ('pain left', 3638),
#  ('self harm', 3402),
#  ('nil phx', 3401),
#  ('pain right', 3397),
#  ('pmh nil', 3388),
#  ('referred gp', 3385),
#  ('speaking sentences', 3366),
#  ('neurovasc intact', 3309),
#  ('pain swelling', 3289),
#  ('hx nil', 3258),
#  ('facial droop', 3146),
#  ('chest tightness', 3143),
#  ('shoulder pain', 3032),
#  ('+ v', 3013),
#  ('non distressed', 3007),
#  ('left leg', 3003),
#  ('n +', 2979),
#  ('nil pain', 2950),
#  ('km hr', 2916),
#  ('sore throat', 2863),
#  ('hs loc', 2828),
#  ('sao2 ra', 2813),
#  ('nil sob', 2792),
#  ('right sided', 2787),
#  ('post fall', 2774),
#  ('headstrike loc', 2729),
#  ('worse inspiration', 2699),
#  ('phx ht', 2697),
#  ('chest infection', 2669),
#  ('left shoulder', 2668),
#  ('blurred vision', 2654),
#  ('denies pain', 2636),
#  ('slurred speech', 2611),
#  ('nausea nil', 2607),
#  ('right hand', 2568),
#  ('mech fall', 2545),
#  ('right leg', 2540),
#  ('right shoulder', 2536),
#  ('nil improvement', 2533),
#  ('sent gp', 2527),
#  ('sided chest', 2521),
#  ('talking sentances', 2513),
#  ('increasing pain', 2503),
#  ('c/o pain', 2477),
#  ('nil hs', 2470),
#  ('oral intake', 2454),
#  ('c spine', 2443),
#  ('seen gp', 2413),
#  ('right knee', 2372),
#  ('generally unwell', 2360),
#  ('right arm', 2324),
#  ('high chol', 2318),
#  ('left hand', 2318),
#  ('nil nausea', 2296),
#  ('nil obvious', 2287),
#  ('urinary symptoms', 2278),
#  ('nil hx', 2270),
#  ('resp distress', 2270),
#  ('vitally stable', 2267),
#  ('knee pain', 2260),
#  ('pst hx', 2231),
#  ('abdominal pain', 2201),
#  ('nil headstrike', 2189),
#  ('suicidal ideation', 2189),
#  ('nil n', 2186),
#  ('assoc nausea', 2159),
#  ('generalised abdo', 2143),
#  ('increasing sob', 2142),
#  ('regular sao2', 2136),
#  ('left knee', 2129),
#  ('hip pain', 2123),
#  ('left chest', 2120),
#  ('pain free', 2107),
#  ('phx asthma', 2093),
#  ('pain nausea', 2074),
#  ('vasc intact', 2070),
#  ('pain assoc', 2048),
#  ('nil analgesia', 2033),
#  ('refered gp', 2031),
#  ('l arm', 2021),
#  ('unwitnessed fall', 2001),
#  ('phx t2', 1996),
#  ('pain r', 1983),
#  ('worse movement', 1980),
#  ('radiating left', 1979),
#  ('lower leg', 1976),
#  ('leg pain', 1975),
#  ('pain l', 1937),
#  ('right ankle', 1927),
#  ('pain hx', 1904),
#  ('triage phx', 1890),
#  ('left eye', 1868),
#  ('left ankle', 1851),
#  ('associated nausea', 1845),
#  ('analgesia taken', 1836),
#  ('l sided', 1828),
#  ('pt c/o', 1811),
#  ('right foot', 1805),
#  ('arm pain', 1790),
#  ('denies loc', 1787),
#  ('oral abs', 1780),
#  ('hx ht', 1777),
#  ('loc nil', 1777),
#  ('phx htn', 1759),
#  ('gcs phx', 1755),
#  ('nil vomiting', 1749),
#  ('left foot', 1743),
#  ('right eye', 1729),
#  ('pmx nil', 1726),
#  ('pain denies', 1703),
#  ('pain pain', 1701),
#  ('nil urinary', 1690),
#  ('dry cough', 1684),
#  ('right flank', 1667),
#  ('phx depression', 1666),
#  ('oral ab', 1664),
#  ('panadeine forte', 1664),
#  ('feels like', 1662),
#  ('pain pmhx', 1656),
#  ('t1 dm', 1656),
#  ('afebrile phx', 1655),
#  ('states pain', 1650),
#  ('yrs ago', 1643),
#  ('self resolved', 1617),
#  ('nil neck', 1594),
#  ('lac left', 1568),
#  ('swelling pain', 1567),
#  ('vomiting diarrhoea', 1556),
#  ('renal colic', 1542),
#  ('denies trauma', 1535),
#  ('right hip', 1535),
#  ('left flank', 1521),
#  ('rif pain', 1502),
#  ('poor historian', 1498),
#  ('head strike', 1489),
#  ('hit head', 1487),
#  ('ongoing pain', 1480),
#  ('left wrist', 1470),
#  ('upper abdo', 1466),
#  ('index finger', 1459),
#  ('sentances non', 1455),
#  ('told present', 1455),
#  ('able ambulate', 1450),
#  ('n vasc', 1442),
#  ('gcs nil', 1432),
#  ('increased pain', 1426),
#  ('chronic pain', 1416),
#  ('talking sentences', 1413),
#  ('pain associated', 1412),
#  ('called av', 1404),
#  ('nv intact', 1403),
#  ('sob nil', 1401),
#  ('dm ht', 1395),
#  ('nil resp', 1395),
#  ('lumbar pain', 1390),
#  ('pr bleeding', 1375),
#  ('saw gp', 1373),
#  ('left lower', 1367),
#  ('lac right', 1357),
#  ('hx t2', 1341),
#  ('onset left', 1341),
#  ('rib pain', 1338),
#  ('right lower', 1337),
#  ('pain rad', 1336),
#  ('phx af', 1334),
#  ('denies urinary', 1325),
#  ('non radiating', 1323),
#  ('triage pmhx', 1312),
#  ('fall ago', 1308),
#  ('states feels', 1307),
#  ('low speed', 1297),
#  ('left hip', 1296),
#  ('hs nil', 1293),
#  ('feeling unwell', 1291),
#  ('worse palpation', 1279),
#  ('assoc sob', 1273),
#  ('s/b gp', 1271),
#  ('l leg', 1270),
#  ('temp hr', 1268),
#  ('loc c/o', 1265),
#  ('right wrist', 1264),
#  ('sob nausea', 1246),
#  ('deep inspiration', 1244),
#  ('pain o/a', 1243),
#  ('self extricated', 1243),
#  ('r sided', 1242),
#  ('decreased rom', 1233),
#  ('nil diarrhoea', 1227),
#  ('gtn patch', 1224),
#  ('worsening pain', 1219),
#  ('hx asthma', 1215),
#  ('gcs hx', 1207),
#  ('l shoulder', 1192),
#  ('triage hx', 1192),
#  ('active bleeding', 1190),
#  ('represent alert', 1190),
#  ('difficult historian', 1189),
#  ('nil effect', 1183),
#  ('pain sob', 1181),
#  ('loc gcs', 1177),
#  ('pain hours', 1168),
#  ('drug use', 1165),
#  ('mg morphine', 1163),
#  ('c/o left', 1162),
#  ('unwell looking', 1162),
#  ('nil chest', 1161),
#  ('o/a talking', 1156),
#  ('neck stiffness', 1154),
#  ('r shoulder', 1149),
#  ('pain unable', 1146),
#  ('r leg', 1142),
#  ('headstrike nil', 1135),
#  ('vitals stable', 1134),
#  ('ankle pain', 1133),
#  ('weight bear', 1118),
#  ('spine tenderness', 1111),
#  ('hep c', 1110),
#  ('r hand', 1105),
#  ('approx km', 1103),
#  ('depression anxiety', 1093),
#  ('ht high', 1093),
#  ('hx depression', 1093),
#  ('ago nil', 1092),
#  ('nil active', 1092),
#  ('pain states', 1088),
#  ('pain relief', 1085),
#  ('recent travel', 1079),
#  ('etoh abuse', 1075),
#  ('frontal headache', 1073),
#  ('worse today', 1071),
#  ('central abdo', 1065),
#  ('etoh +', 1063),
#  ('cm lac', 1060),
#  ('vs car', 1060),
#  ('unable tolerate', 1056),
#  ('pain pt', 1054),
#  ('ruq pain', 1054),
#  ('r arm', 1051),
#  ('nil altered', 1050),
#  ('years ago', 1049),
#  ('nil cp', 1047),
#  ('nil recent', 1046),
#  ('rr sao2', 1034),
#  ('onset hours', 1032),
#  ('obvious deformity', 1031),
#  ('sharp nature', 1031),
#  ('pain today', 1025),
#  ('dizziness nausea', 1023),
#  ('distressed phx', 1021),
#  ('pain increasing', 1021),
#  ('pain gcs', 1014),
#  ('r knee', 1011),
#  ('nil pmhx', 1010),
#  ('unable weight', 1010),
#  ('mg iv', 1006),
#  ('gcs hr', 1005),
#  ('c/o right', 1004),
#  ('l hand', 1004),
#  ('triage nil', 1004),
#  ('feeling dizzy', 1001),
#  ('hr phx', 1000),
#  ('denies neck', 999),
#  ('hours onset', 999),
#  ('referred lmo', 999),
#  ('pt reports', 996),
#  ('unconscious collapse', 996),
#  ('unable sleep', 994),
#  ('nil trauma', 990),
#  ('middle finger', 989),
#  ('hr bp', 988),
#  ('intact phx', 988),
#  ('dm htn', 987),
#  ('feeling generally', 987),
#  ('vomit x', 987),
#  ('c/o headache', 983),
#  ('oa hr', 982),
#  ('worsening sob', 977),
#  ('hx af', 975),
#  ('triage gcs', 971),
#  ('renal failure', 970),
#  ('gcs confused', 969),
#  ('post eating', 967),
#  ('intact nil', 966),
#  ('phx ami', 964),
#  ('l knee', 959),
#  ('nil fevers', 956),
#  ('pain pmh', 955),
#  ('x vomit', 954),
#  ('foot pain', 953),
#  ('nil facial', 949),
#  ('denies chest', 948),
#  ('pain sharp', 944),
#  ('increased sob', 943),
#  ('phx anxiety', 943),
#  ('unable wb', 943),
#  ('flu like', 942),
#  ('bp hr', 935),
#  ('code stroke', 935),
#  ('anxiety depression', 933),
#  ('like symptoms', 932),
#  ('o/a painfree', 932),
#  ('painful right', 932),
#  ('small lac', 932),
#  ('etoh tonight', 930),
#  ('today nil', 930),
#  ('unsteady gait', 921),
#  ('av arrival', 919),
#  ('chest discomfort', 915),
#  ('urinary bowel', 915),
#  ('eye contact', 914),
#  ('similar episode', 912),
#  ('groin pain', 908),
#  ('urinary frequency', 907),
#  ('wrist pain', 907),
#  ('headache nil', 900),
#  ('nil airway', 898),
#  ('conscious collapse', 896),
#  ('vomiting nil', 891),
#  ('alleged assault', 890),
#  ('approx cm', 889),
#  ('pmhx ht', 886),
#  ('airbags deployed', 884),
#  ('d/c rmh', 884),
#  ('thoracic pain', 884),
#  ('onset central', 876),
#  ('mcg fentanyl', 874),
#  ('radiating right', 874),
#  ('visual disturbance', 874),
#  ('left elbow', 871),
#  ('tonic clonic', 871),
#  ('pmhx t2', 870),
#  ('v +', 870),
#  ('chest heaviness', 869),
#  ('onset right', 866),
#  ('r ankle', 865),
#  ('afebrile triage', 864),
#  ('decreased oral', 862),
#  ('l chest', 861),
#  ('distressed triage', 856),
#  ('worse deep', 856),
#  ('fall standing', 855),
#  ('mental health', 855),
#  ('pins needles', 855),
#  ('av called', 853),
#  ('good effect', 852),
#  ('states feeling', 852),
#  ('pain past', 851),
#  ('pmhx asthma', 851),
#  ('spine pain', 850),
#  ('sharp pain', 848),
#  ('anxious +', 846),
#  ('gcs pearl', 845),
#  ('body aches', 843),
#  ('o/a pain', 843),
#  ('difficulty ambulating', 842),
#  ('pmh ht', 842),
#  ('sided weakness', 838),
#  ('right elbow', 837),
#  ('associated sob', 835),
#  ('dm insulin', 834),
#  ('o/a hr', 834),
#  ('hx ami', 828),
#  ('gcs o/a', 827),
#  ('swollen painful', 827),
#  ('sided abdo', 825),
#  ('pain worsening', 824),
#  ('difficulty swallowing', 820),
#  ('aches pains', 818),
#  ('phx dementia', 817),
#  ('nil neurology', 814),
#  ('fracture right', 813),
#  ('ht ^chol', 812),
#  ('l eye', 811),
#  ('r eye', 811),
#  ('r foot', 811),
#  ('recent admission', 809),
#  ('syncopal episode', 809),
#  ('x mg', 808),
#  ('urinary sx', 807),
#  ('nil radiation', 806),
#  ('pt denies', 803),
#  ('fall headstrike', 800),
#  ('ht t2', 800),
#  ('onset dizziness', 800),
#  ('phx renal', 800),
#  ('swelling right', 798),
#  ('gp today', 797),
#  ('nil recall', 797),
#  ('painful left', 797),
#  ('swelling left', 796),
#  ('fracture left', 793),
#  ('nvac intact', 793),
#  ('pain palpation', 793),
#  ('ago phx', 792),
#  ('nil distress', 792),
#  ('staff member', 790),
#  ('l foot', 785),
#  ('hx htn', 782),
#  ('equal limb', 775),
#  ('oa gcs', 774),
#  ('recall event', 773),
#  ('nil symptoms', 772),
#  ('present ed', 769),
#  ('inspiration movement', 767),
#  ('radial pulse', 765),
#  ('aspirin gtn', 763),
#  ('phx schizophrenia', 760),
#  ('phx copd', 759),
#  ('av phx', 758),
#  ('left thumb', 755),
#  ('little finger', 754),
#  ('similar previous', 752),
#  ('afebrile nil', 750),
#  ('severe pain', 750),
#  ('painfree phx', 743),
#  ('post gtn', 742),
#  ('av given', 740),
#  ('iv morphine', 740),
#  ('pain lower', 740),
#  ('pmhx htn', 740),
#  ('given mg', 739),
#  ('driver mva', 738),
#  ('seen ed', 737),
#  ('minimal relief', 736),
#  ('sob phx', 735),
#  ('loc recall', 734),
#  ('l ankle', 733),
#  ('recall events', 732),
#  ('triage pmh', 732),
#  ('chest clear', 731),
#  ('nausea +', 728),
#  ('pain vomiting', 728),
#  ('abdo cramping', 725),
#  ('hr sr', 725),
#  ('nausea vomitting', 723),
#  ('pain yesterday', 723),
#  ('direct resus', 722),
#  ('felt dizzy', 721),
#  ('af warfarin', 718),
#  ('denies fevers', 718),
#  ('lac head', 718),
#  ('obvious injuries', 717),
#  ('pain increased', 717),
#  ('able wb', 715),
#  ('pain difficulty', 715),
#  ('post ictal', 714),
#  ('denies nausea', 712),
#  ('urinary retention', 712),
#  ('calf pain', 711),
#  ('headache nausea', 710),
#  ('pain seen', 710),
#  ('radiating l', 710),
#  ('hx left', 709),
#  ('nausea phx', 707),
#  ('chemo ago', 706),
#  ('getting worse', 705),
#  ('generalised weakness', 704),
#  ('distress speaking', 703),
#  ('looks pale', 703),
#  ('sob chest', 703),
#  ('r flank', 702),
#  ('standing height', 702),
#  ('taken analgesia', 701),
#  ('lac l', 699),
#  ('o/a afebrile', 699),
#  ('right chest', 698),
#  ('gcs =', 697),
#  ('post mechanical', 696),
#  ('th finger', 696),
#  ('nausea dizziness', 695),
#  ('left ear', 693),
#  ('recent chest', 693),
#  ('seen rmh', 693),
#  ('intermittent chest', 692),
#  ('jaw pain', 692),
#  ('gcs normal', 690),
#  ('phx cva', 690),
#  ('htn ^chol', 687),
#  ('push bike', 685),
#  ('sao2 bp', 685),
#  ('+ nausea', 684),
#  ('hr irregular', 680),
#  ('right ear', 679),
#  ('short sentences', 677),
#  ('neuro vasc', 675),
#  ('pain resolved', 675),
#  ('hx right', 674),
#  ('hit car', 671),
#  ('right thumb', 671),
#  ('nil assoc', 670),
#  ('blood loss', 669),
#  ('high cholesterol', 669),
#  ('loc headstrike', 669),
#  ('gp nil', 666),
#  ('hot touch', 665),
#  ('left facial', 665),
#  ('normal pt', 664),
#  ('cardiac hx', 663),
#  ('commenced oral', 662),
#  ('renal transplant', 662),
#  ('decreased mobility', 660),
#  ('hx dementia', 660),
#  ('seizure activity', 655),
#  ('nil visual', 654),
#  ('states unable', 654),
#  ('hr temp', 652),
#  ('high speed', 651),
#  ('phx epilepsy', 651),
#  ('l wrist', 650),
#  ('gcs triage', 649),
#  ('pain decreased', 649),
#  ('nausea sob', 648),
#  ('today pain', 648),
#  ('pain night', 647),
#  ('ring finger', 647),
#  ('nil change', 646),
#  ('x episodes', 646),
#  ('increased wob', 645),
#  ('family hx', 644),
#  ('denies cp', 642),
#  ('playing football', 641),
#  ('pain urination', 639),
#  ('neuro intact', 638),
#  ('sentences nil', 638),
#  ('suicidal thoughts', 637),
#  ('left cp', 635),
#  ('onset sob', 633),
#  ('hx anxiety', 631),
#  ('big toe', 630),
#  ('painful swollen', 629),
#  ('limited rom', 628),
#  ('morphine mg', 628),
#  ('limb strength', 625),
#  ('pain non', 625),
#  ('sided facial', 625),
#  ('v nil', 624),
#  ('days ago', 623),
#  ('thoughts self', 623),
#  ('lac r', 622),
#  ('s/b lmo', 622),
#  ('symptoms phx', 622),
#  ('minimal pain', 621),
#  ('l flank', 619),
#  ('nil headache', 618),
#  ('r hip', 617),
#  ('loc neck', 616),
#  ('chest pressure', 614),
#  ('playing soccer', 614),
#  ('hr bpm', 611),
#  ('left face', 610),
#  ('o/a nil', 610),
#  ('denies pmh', 609),
#  ('kidney stones', 609),
#  ('light headed', 608),
#  ('painfree post', 607),
#  ('hx renal', 605),
#  ('symptoms nil', 605),
#  ('av hx', 604),
#  ('rlq pain', 604),
#  ('av gcs', 603),
#  ('sob +', 602),
#  ('l hip', 601),
#  ('weight bare', 601),
#  ('denies sob', 600),
#  ('ago post', 598),
#  ('helmet worn', 598),
#  ('post mva', 598),
#  ('pain c/o', 596),
#  ('pain chest', 595),
#  ('pain onset', 595),
#  ('gcs afebrile', 594),
#  ('c/o nausea', 593),
#  ('gcs pmh', 593),
#  ('generalised aches', 593),
#  ('nil neuro', 593),
#  ('collar insitu', 591),
#  ('gtn spray', 591),
#  ('pmhx depression', 591),
#  ('sided cp', 591),
#  ('sob pain', 591),
#  ('swelling post', 591),
#  ('deep lac', 589),
#  ('nil injuries', 589),
#  ('pain intermittent', 589),
#  ('worse insp', 589),
#  ('oral antis', 588),
#  ('head nil', 587),
#  ('af ht', 584),
#  ('left upper', 582),
#  ('prod cough', 582),
#  ('right upper', 582),
#  ('loc o/a', 581),
#  ('non compliant', 580),
#  ('approx hours', 579),
#  ('d/c ago', 579),
#  ('denies phx', 578),
#  ('hx copd', 578),
#  ('phx cags', 578),
#  ('pt requesting', 578),
#  ('o/a unwell', 573),
#  ('c/o dizziness', 572),
#  ('found floor', 572),
#  ('pmh asthma', 572),
#  ('pmh depression', 572),
#  ('c/o neck', 571),
#  ('burning urination', 570),
#  ('brief loc', 569),
#  ('av o/a', 568),
#  ('swelling redness', 568),
#  ('ph nil', 567),
#  ('distress triage', 565),
#  ('poor oral', 564),
#  ('onset ccp', 563),
#  ('pain n', 563),
#  ('pain similar', 563),
#  ('looking hr', 559),
#  ('ped vs', 559),
#  ('arm numbness', 558),
#  ('nil significant', 558),
#  ('pain afebrile', 558),
#  ('phx recent', 558),
#  ('post etoh', 558),
#  ('ago pt', 557),
#  ('arm weakness', 557),
#  ('passing urine', 557),
#  ('past days', 557),
#  ('r wrist', 556),
#  ('facial swelling', 555),
#  ('leg weakness', 555),
#  ('mild headache', 555),
#  ('mild pain', 555),
#  ('bowel symptoms', 554),
#  ('sob productive', 554),
#  ('unable ambulate', 554),
#  ('sr monitor', 553),
#  ('bp phx', 552),
#  ('elbow pain', 552),
#  ('pain currently', 552),
#  ('requesting help', 552),
#  ('diarrhoea nil', 551),
#  ('ps nil', 551),
#  ('clonic seizure', 550),
#  ('fall ladder', 550),
#  ('gp letter', 550),
#  ('nil associated', 550),
#  ('temp triage', 550),
#  ('swelling nil', 549),
#  ('ecg changes', 547),
#  ('pain neck', 546),
#  ('hx cva', 545),
#  ('onset severe', 545),
#  ('onset sharp', 545),
#  ('hemodynamically stable', 544),
#  ('onset chest', 544),
#  ('respiratory distress', 544),
#  ('assoc symptoms', 543),
#  ('pain able', 542),
#  ('av pmhx', 541),
#  ('hx schizophrenia', 541),
#  ('speed mva', 541),
#  ('ht chol', 540),
#  ('pain movement', 540),
#  ('ear pain', 539),
#  ('en route', 539),
#  ('gp given', 539),
#  ('radiating groin', 539),
#  ('rear ended', 539),
#  ('unsteady feet', 538),
#  ('limb weakness', 537),
#  ('o/a mild', 537),
#  ('today phx', 537),
#  ('pt unable', 536),
#  ('weight loss', 536),
#  ('lower limb', 535),
#  ('pain ph', 535),
#  ('cabin intrusion', 533),
#  ('gp hx', 533),
#  ('pain recent', 533),
#  ('upper arm', 533),
#  ('hr sao2', 532),
#  ('nursing home', 532),
#  ('o/a resp', 531),
#  ('r lower', 531),
#  ('right face', 531),
#  ('ago pain', 530),
#  ('gcs pmhx', 530),
#  ('left calf', 530),
#  ('loc pain', 530),
#  ('radiating neck', 529),
#  ('difficulty breathing', 528),
#  ('fall nil', 528),
#  ('left forearm', 528),
#  ('nil swelling', 528),
#  ('sob worse', 528),
#  ('allergic reaction', 526),
#  ('cp sob', 526),
#  ('poor recall', 526),
#  ('sao2 l', 526),
#  ('swelling +', 525),
#  ('fall hs', 524),
#  ('mild swelling', 524),
#  ('peter mac', 524),
#  ('movement nil', 522),
#  ('pain diarrhoea', 522),
#  ('pain hr', 522),
#  ('htn t2', 521),
#  ('leg swelling', 521),
#  ('hand pain', 520),
#  ('recent d/c', 520),
#  ('inspiration palpation', 519),
#  ('pmhx af', 519),
#  ('speaking short', 519),
#  ('sentences hr', 517),
#  ('able weight', 516),
#  ('c/o sob', 515),
#  ('pain triage', 515),
#  ('nil abdo', 513),
#  ('o/a ps', 513),
#  ('+ pain', 512),
#  ('redness swelling', 512),
#  ('valve replacement', 512),
#  ('decreased appetite', 511),
#  ('denies headstrike', 511),
#  ('gp referral', 511),
#  ('pmh t2', 511),
#  ('ps phx', 511),
#  ('seen ago', 511),
#  ('ago o/a', 510),
#  ('looks uncomfortable', 509),
#  ('stable triage', 509),
#  ('+ vomiting', 508),
#  ('sb gp', 508),
#  ('gcs av', 507),
#  ('sharp chest', 507),
#  ('pt feels', 506),
#  ('phx ccf', 505),
#  ('c/o lower', 504),
#  ('gradual onset', 504),
#  ('mild nausea', 504),
#  ('unable recall', 504),
#  ('fall left', 502),
#  ('hours nil', 502),
#  ('intermittent left', 502),
#  ('ccp radiating', 500),
#  ('phx ihd', 500),
#  ('pr bleed', 500),
#  ('pain headache', 499),
#  ('right facial', 499),
#  ('abdo cramps', 498),
#  ('symptoms resolved', 498),
#  ('sensation left', 497),
#  ('pain improved', 495),
#  ('frank blood', 494),
#  ('htn high', 494),
#  ('pain feels', 494),
#  ('auditory hallucinations', 493),
#  ('phx ppm', 493),
#  ('ecg nad', 492),
#  ('fall right', 492),
#  ('hernia repair', 492),
#  ('pain relieved', 492),
#  ('conscious state', 491),
#  ('cough nil', 491),
#  ('loose stools', 491),
#  ('currently painfree', 488),
#  ('hr nil', 488),
#  ('swelling r', 488),
#  ('states nil', 487),
#  ('phx chronic', 486),
#  ('+ phx', 485),
#  ('l lower', 485),
#  ('nil c', 485),
#  ('nil vomit', 485),
#  ('regular bp', 484),
#  ('collared av', 483),
#  ('left neck', 483),
#  ('nil oa', 483),
#  ('onset headache', 483),
#  ('red swollen', 483),
#  ('actively bleeding', 480),
#  ('cardiac stents', 480),
#  ('right neck', 480),
#  ('+ sob', 479),
#  ('hx epilepsy', 479),
#  ('nil bowel', 479),
#  ('alt sensation', 478),
#  ('non productive', 478),
#  ('swelling l', 478),
#  ('hr triage', 477),
#  ('rmh ago', 477),
#  ('feeling sob', 476),
#  ('x vomits', 476),
#  ('chest wall', 475),
#  ('denies n', 474),
#  ('o/a phx', 474),
#  ('seat belt', 474),
#  ('brain tumour', 473),
#  ('went gp', 473),
#  ('nausea diaphoresis', 471),
#  ('temp phx', 471),
#  ('left index', 469),
#  ('nil changes', 469),
#  ('direct t1', 468),
#  ('headache dizziness', 468),
#  ('pt concerned', 468),
#  ('arm nil', 467),
#  ('burning sensation', 467),
#  ('o/a p/s', 467),
#  ('onset palpitations', 466),
#  ('home o2', 465),
#  ('intact hx', 465),
#  ('lower abdominal', 465),
#  ('yesterday nil', 465),
#  ('inguinal hernia', 464),
#  ('right calf', 464),
#  ('afebrile hx', 463),
#  ('denies headache', 462),
#  ('stable phx', 461),
#  ('fracture r', 460),
#  ('viewed triage', 460),
#  ('sob dizziness', 459),
#  ('associated symptoms', 458),
#  ('inc sob', 458),
#  ('lac forehead', 458),
#  ('mild sob', 458),
#  ('swollen right', 458),
#  ('bilateral lower', 457),
#  ('hx cags', 457),
#  ('intact pmhx', 457),
#  ('nausea diarrhoea', 457),
#  ('airway compromise', 456),
#  ('c/o feeling', 456),
#  ('cough sob', 456),
#  ('palpation nil', 456),
#  ('appears pale', 455),
#  ('mva km', 455),
#  ('onset l', 455),
#  ('eye pain', 454),
#  ('numbness left', 454),
#  ('post falling', 454),
#  ('shortening rotation', 454),
#  ('occipital headache', 453),
#  ('nil cough', 452),
#  ('ref gp', 452),
#  ('assoc dizziness', 451),
#  ('pt presents', 451),
#  ('bowel urinary', 450),
#  ('inspiration nil', 450),
#  ('bilateral leg', 449),
#  ('loc lac', 449),
#  ('today pt', 449),
#  ('hours ago', 448),
#  ('increased swelling', 448),
#  ('pt fell', 448),
#  ('hearing voices', 447),
#  ('morphine av', 447),
#  ('approx mins', 446),
#  ('assoc n', 446),
#  ('bilateral flank', 446),
#  ('direct t2', 445),
#  ('painful r', 445),
#  ('droop slurred', 444),
#  ('loc phx', 444),
#  ('nausea denies', 444),
#  ('onset lower', 444),
#  ('pain inspiration', 444),
#  ('rad left', 444),
#  ('right forearm', 444),
#  ('denies recent', 443),
#  ('sob hx', 443),
#  ('c/o chest', 442),
#  ('hours sudden', 442),
#  ('mcg gtn', 442),
#  ('phx etoh', 442),
#  ('woke hours', 442),
#  ('burning pain', 440),
#  ('fall yesterday', 440),
#  ('strong radial', 440),
#  ('onset epigastric', 439),
#  ('seat passenger', 439),
#  ('severe headache', 439),
#  ('sighted triage', 439),
#  ('left breast', 438),
#  ('pitting oedema', 438),
#  ('hand post', 437),
#  ('kidney transplant', 437),
#  ('loc denies', 435),
#  ('n surg', 435),
#  ('improved post', 434),
#  ('hx worsening', 433),
#  ('cough fevers', 432),
#  ('denies drug', 432),
#  ('phx niddm', 432),
#  ('testicular pain', 432),
#  ('+ nil', 431),
#  ('fracture post', 431),
#  ('feeling hot', 430),
#  ('bowel obstruction', 429),
#  ('lives home', 429),
#  ('pain burning', 429),
#  ('right abdo', 429),
#  ('right groin', 429),
#  ('today hx', 429),
#  ('fevers chills', 428),
#  ('weight bearing', 428),
#  ('headache +', 427),
#  ('hot cold', 427),
#  ('o/a hx', 427),
#  ('royal park', 427),
#  ('fracture l', 426),
#  ('relief panadol', 426),
#  ('tolerate oral', 426),
#  ('cp worse', 425),
#  ('dizziness nil', 424),
#  ('stable av', 424),
#  ('pain pmx', 423),
#  ('sentences sao2', 423),
#  ('ex smoker', 422),
#  ('nil photophobia', 422),
#  ('recent uti', 422),
#  ('relief gtn', 422),
#  ('visual disturbances', 422),
#  ('worsening right', 421),
#  ('fall today', 420),
#  ('pain abdo', 420),
#  ('radiating nil', 420),
#  ('hard collar', 419),
#  ('advised present', 418),
#  ('afebrile pain', 418),
#  ('landing left', 418),
#  ('movement palpation', 418),
#  ('nad phx', 418),
#  ('oral abx', 418),
#  ('vp shunt', 418),
#  ('+ swelling', 417),
#  ('ankle post', 417),
#  ('lower limbs', 417),
#  ('retrograde amnesia', 417),
#  ('sob diaphoresis', 417),
#  ('ago hx', 415),
#  ('headache phx', 415),
#  ('post mech', 415),
#  ('recent stressors', 415),
#  ('nausea pain', 414),
#  ('etoh today', 413),
#  ('gcs denies', 413),
#  ('swollen left', 413),
#  ('throat pain', 413),
#  ('appears comfortable', 412),
#  ('c/o abdo', 412),
#  ('exp wheeze', 412),
#  ('applied triage', 411),
#  ('throat tightness', 411),
#  ('today c/o', 411),
#  ('worsening left', 411),
#  ('febrile triage', 409),
#  ('pt found', 408),
#  ('right index', 408),
#  ('intact pain', 407),
#  ('o/a temp', 407),
#  ('phx smoker', 407),
#  ('diarrhoea vomiting', 406),
#  ('ht af', 406),
#  ('ongoing nausea', 406),
#  ('pain mild', 406),
#  ('av nil', 405),
#  ('dec rom', 405),
#  ('ice use', 405),
#  ('nil deformity', 405),
#  ...]

# %%
df_train.entities.str.contains("hx").sum()
# Out:
# 155483

# %%
plt.hist(bigrams.values(), bins=100);
plt.xlim([20000, 30000]);
plt.ylim([0, 10]);

# %% [markdown]
# ## Synonyms

# %%
df_train.entities.str.contains("\+").sum()
# Out:
# 24243

# %%
df_train.entities[df_train.entities.str.contains("\+")]
# Out:
# 27                                 playing soccer knee locked pain + fall ground nil hs tx penthrane morphine
# 73        represent alert intermittent pic seen yesterday referred gp today ongoing l lateral pic + fever ...
# 77                                   etoh + drugs unsure hours fell taxi nil headstrike loc feeling weak post
# 80        woke feeling nauseated following tooth extraction thurs a/w slight ^ lower jaw swelling + shakes...
# 87                                                                     dizziness + unsteady gait ph pacemaker
#                                                          ...
# 311513                     found street av aggressive + confronting people street pmh unknown known john cade
# 311514    fall home r/t ms + mobility aids hit head shoulder loc incomplete recall events haematoma head s...
# 311525                 etoh foosh left arm slight numbness fingers pain + limited movement swelling elbow phx
# 311528                          od seroquel x + diazepam x past hours aggitated + aggressive phx bipolar ptsd
# 311532                    bleeding attempted drainage cyst r arm clexane ph metastatic melanoma + multiple pe
# Name: entities, Length: 24243, dtype: object

# %%
import json

with open('../Final/data/synonym.json') as json_file:
    synonyms = json.load(json_file)

# %%
synonyms

# %% [markdown]
# ## Character n-grams w/o preprocessing

# %%
i
# Out:
# 45432

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'),
                             analyzer='char', ngram_range=(2,4))
vectors = vectorizer.fit_transform(df_raw.comment.str.lower())

# %%
vocab = vectorizer.vocabulary_
len(vocab)

# %% [markdown]
# ## Tokenize

# %%
vectorizer = TfidfVectorizer(stop_words=stopwords.words('english'))
vectors = vectorizer.fit_transform(df_new.comment)

# %%
vocab = vectorizer.vocabulary_
len(vocab)
